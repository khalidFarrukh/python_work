# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Conduct an alpha-beta pruning by generating left-most nodes first.
# - Print the values of Alpha and Beta for each Node.
# - Print the Minimax values of each node.
# - Print the Optimal value of top node.
# - Print the Path till the leaf from where we get the Optimal Value.
